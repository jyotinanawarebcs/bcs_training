# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
data = {
    "Name": ["Amit", "Riya", "John"],
    "Age": [25, 30, 22],
    "City": ["Delhi", "Mumbai", "Pune"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Name  Age    City
# 0  Amit   25   Delhi
# 1  Riya   30  Mumbai
# 2  John   22    Pune

# %%
df["Age"].plot(kind="bar")
# Out:
# <Axes: >

# %%
plt.show()
